# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
titanic_train = pd.read_csv("train.csv")
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_train['Age'].fillna(titanic_train.groupby('Pclass')['Age'].transform('median'),inplace = True)

# %%
titanic_train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_train=titanic_train.drop(['Name','Ticket','Fare','Cabin'],axis=1)

# %%
titanic_train.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Embarked       2
# dtype: int64

# %%
titanic_train=titanic_train[titanic_train['Embarked'].notna()]

# %%
titanic_train['Family']=titanic_train['SibSp']+titanic_train['Parch']

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked  \
# 0              1         0       3    male  22.0      1      0        S
# 1              2         1       1  female  38.0      1      0        C
# 2              3         1       3  female  26.0      0      0        S
# 3              4         1       1  female  35.0      1      0        S
# 4              5         0       3    male  35.0      0      0        S
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0        S
# 887          888         1       1  female  19.0      0      0        S
# 888          889         0       3  female  24.0      1      2        S
# 889          890         1       1    male  26.0      0      0        C
# 890          891         0       3    male  32.0      0      0        Q
#
#      Family
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
# ..      ...
# ...

# %%
titanic_train=titanic_train.drop(['SibSp','Parch'],axis=1)

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age Embarked  Family
# 0              1         0       3    male  22.0        S       1
# 1              2         1       1  female  38.0        C       1
# 2              3         1       3  female  26.0        S       0
# 3              4         1       1  female  35.0        S       1
# 4              5         0       3    male  35.0        S       0
# ..           ...       ...     ...     ...   ...      ...     ...
# 886          887         0       2    male  27.0        S       0
# 887          888         1       1  female  19.0        S       0
# 888          889         0       3  female  24.0        S       3
# 889          890         1       1    male  26.0        C       0
# 890          891         0       3    male  32.0        Q       0
#
# [889 rows x 7 columns]

# %%
x = titanic_train.drop(['PassengerId','Survived'],axis =1)
x = pd.get_dummies(x)

# %%
x
# Out:
#      Pclass   Age  Family  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0         3  22.0       1           0         1           0           0
# 1         1  38.0       1           1         0           1           0
# 2         3  26.0       0           1         0           0           0
# 3         1  35.0       1           1         0           0           0
# 4         3  35.0       0           0         1           0           0
# ..      ...   ...     ...         ...       ...         ...         ...
# 886       2  27.0       0           0         1           0           0
# 887       1  19.0       0           1         0           0           0
# 888       3  24.0       3           1         0           0           0
# 889       1  26.0       0           0         1           1           0
# 890       3  32.0       0           0         1           0           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# ...

# %%
y = titanic_train.Survived

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=6)

# %%
rfc = RandomForestClassifier(random_state=3)
rfc.fit(x_train,y_train)
accuracy_score(y_test,rfc.predict(x_test))
# Out:
# 0.797752808988764

# %%
from lightgbm import LGBMClassifier

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

# %%
def cval(x, y,estimator,params,folds):

    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=17)
    
    for fold, (train_idx, test_idx) in enumerate(skf.split(x, y)):
        x_train, y_train = x.iloc[train_idx], y.iloc[train_idx]
        x_test, y_test = x.iloc[test_idx], y.iloc[test_idx]

        model = estimator(**params)
        model.fit(x_train, y_train, eval_set=[(x_test, y_test)], early_stopping_rounds=100, verbose=0)
        accu = accuracy_score(y_test, model.predict(x_test))
        
        print(str(fold+1)+' Fold Accuracy: '+str(accu))
        print("-"*50)
    
    return model

# %%
params = {'learning_rate':0.1,'min_child_samples':14,'reg_alpha':7,'reg_lambda':7}

lgbm = cval(x,y,LGBMClassifier,params,5)
# Out:
# 1 Fold Accuracy: 0.8370786516853933
# --------------------------------------------------
# 2 Fold Accuracy: 0.7865168539325843
# --------------------------------------------------
# 3 Fold Accuracy: 0.8033707865168539
# --------------------------------------------------
# 4 Fold Accuracy: 0.8314606741573034
# --------------------------------------------------
# 5 Fold Accuracy: 0.7966101694915254
# --------------------------------------------------

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=6)

# %%
accuracy_score(y_test,lgbm.predict(x_test))
# Out:
# 0.848314606741573

# %%
titanic_test = pd.read_csv('test.csv')
titanic_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
titanic_test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic_test=titanic_test.drop(['Name','Ticket','Fare','Cabin'],axis=1)

# %%
titanic_test['Age'].fillna(titanic_test.groupby('Pclass')['Age'].transform('median'),inplace = True)

# %%
titanic_test['Family']=titanic_test['SibSp']+titanic_test['Parch']

# %%
titanic_test=titanic_test.drop(['SibSp','Parch'],axis=1)

# %%
titanic_test
# Out:
#      PassengerId  Pclass     Sex   Age Embarked  Family
# 0            892       3    male  34.5        Q       0
# 1            893       3  female  47.0        S       1
# 2            894       2    male  62.0        Q       0
# 3            895       3    male  27.0        S       0
# 4            896       3  female  22.0        S       2
# ..           ...     ...     ...   ...      ...     ...
# 413         1305       3    male  24.0        S       0
# 414         1306       1  female  39.0        C       0
# 415         1307       3    male  38.5        S       0
# 416         1308       3    male  24.0        S       0
# 417         1309       3    male  24.0        C       2
#
# [418 rows x 6 columns]

# %%
id=titanic_test.PassengerId

# %%
titanic_test.drop(['PassengerId'],axis = 1,inplace= True)

# %%
titanic_test = pd.get_dummies(titanic_test)

# %%
titanic_test
# Out:
#      Pclass   Age  Family  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0         3  34.5       0           0         1           0           1
# 1         3  47.0       1           1         0           0           0
# 2         2  62.0       0           0         1           0           1
# 3         3  27.0       0           0         1           0           0
# 4         3  22.0       2           1         0           0           0
# ..      ...   ...     ...         ...       ...         ...         ...
# 413       3  24.0       0           0         1           0           0
# 414       1  39.0       0           1         0           1           0
# 415       3  38.5       0           0         1           0           0
# 416       3  24.0       0           0         1           0           0
# 417       3  24.0       2           0         1           1           0
#
#      Embarked_S
# 0             0
# 1             1
# 2             0
# 3             1
# ...

# %%
pred = lgbm.predict(titanic_test)

# %%
submission = pd.DataFrame({'PassengerId':id,'Survived':pred})

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
submission.to_csv('submission.csv',index=False)
